# %%
from src.dataset_csv import ImageCSVDataset
import numpy as np
import matplotlib.pyplot as plt

# %%
IMAGE_PATH = "/cluster/tufts/hugheslab/datasets/IDRID/Images/"
TRAIN_LABEL_PATH = "/cluster/tufts/hugheslab/datasets/IDRID/Labels/train.csv"
TEST_LABEL_PATH = "/cluster/tufts/hugheslab/datasets/IDRID/Labels/test.csv"
train_idrid_dataset = ImageCSVDataset(csv_file=TRAIN_LABEL_PATH, root_dir=IMAGE_PATH, transform=None, transforms=None)
test_idrid_dataset = ImageCSVDataset(csv_file=TEST_LABEL_PATH, root_dir=IMAGE_PATH, transform=None, transforms=None)

# %%
# Plot some sample images and labels
for i, sample in enumerate(test_idrid_dataset):
        print(i, sample[0].shape, sample[1].shape)

        ax = plt.subplot(1, 4, i + 1)
        plt.tight_layout()
        ax.set_title(f"Label: {sample[1]}")
        ax.axis('off')
        plt.imshow(sample[0])

        if i == 3:
                plt.show()
                break
# Out:
# 0 (2848, 4288, 3) ()
# 1 (2848, 4288, 3) ()
# 2 (2848, 4288, 3) ()
# 3 (2848, 4288, 3) ()
