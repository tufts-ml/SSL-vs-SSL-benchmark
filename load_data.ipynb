# %%
import numpy as np
from PIL import Image
from src.dataset import data
from torch.utils.data import DataLoader

# %%
l_train_dataset = data(dataset_name='IDRID', dataset_path='train_data.npy', transform_fn=None)
test_dataset = data(dataset_name='IDRID', dataset_path='test_data.npy', transform_fn=None)

image, label = l_train_dataset[0] # image is a PIL image, label is an integer
print("Label:", label)
image.show()

print('Created dataset')
print("labeled data : {}, training data : {}".format(
len(l_train_dataset), len(l_train_dataset)))
# Out:
# Label: 3

# %%
l_loader = DataLoader(l_train_dataset, 10, shuffle=True, drop_last=True, num_workers=3)

# %%
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x1B9FA77BD90>
